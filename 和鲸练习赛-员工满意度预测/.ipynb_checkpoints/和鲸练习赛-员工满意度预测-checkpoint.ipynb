# %% [markdown]
# # 测试Keras环境

# %%
import keras
keras.__version__
# Out:
# '2.3.1'

# %% [markdown]
# # 数据准备

# %% [markdown]
# ## 提取数据

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data_train=pd.read_csv("../和鲸练习赛-员工满意度预测/data/训练集.csv")
data_test=pd.read_csv("../和鲸练习赛-员工满意度预测/data/测试集.csv")

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11999 entries, 0 to 11998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     11999 non-null  int64
#  1   last_evaluation        11999 non-null  float64
#  2   number_project         11999 non-null  int64
#  3   average_monthly_hours  11999 non-null  float64
#  4   time_spend_company     11999 non-null  int64
#  5   Work_accident          11999 non-null  int64
#  6   package                11999 non-null  object
#  7   promotion_last_5years  11999 non-null  int64
#  8   division               11999 non-null  object
#  9   salary                 11999 non-null  object
#  10  satisfaction_level     11999 non-null  float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 1.0+ MB

# %%
data_train.head(5)
# Out:
#       id  last_evaluation  number_project  average_monthly_hours  \
# 0  13697             0.99               3                 161.39
# 1   1142             1.00               5                 226.22
# 2   7954             0.91               5                 199.45
# 3   2225             0.51               3                 235.14
# 4   9753             0.89               3                 219.91
#
#    time_spend_company  Work_accident package  promotion_last_5years  \
# 0                   2              0       a                      0
# 1                   6              0       b                      0
# 2                   2              0       e                      0
# 3                   3              0       c                      0
# 4                   2              0       a                      0
#
#      division  salary  satisfaction_level
# 0  accounting  medium               0.681
# 1   marketing     low               0.876
# 2       sales  medium               0.955
# 3       sales     low               0.817
# 4   technical     low               0.920

# %% [markdown]
# ## 类别变量转化为数字变量

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data_train["package"]=le.fit_transform(data_train["package"])
data_test["package"]=le.fit_transform(data_test["package"])
data_train["division"]=le.fit_transform(data_train["division"])
data_test["division"]=le.fit_transform(data_test["division"])
data_train["salary"]=le.fit_transform(data_train["salary"])
data_test["salary"]=le.fit_transform(data_test["salary"])

# %% [markdown]
# ## 检测异常值

# %%
data_train.isnull().any()
# Out:
# id                       False
# last_evaluation          False
# number_project           False
# average_monthly_hours    False
# time_spend_company       False
# Work_accident            False
# package                  False
# promotion_last_5years    False
# division                 False
# salary                   False
# satisfaction_level       False
# dtype: bool

# %% [markdown]
# ## 获取X和y

# %%
data_train
# Out:
#           id  last_evaluation  number_project  average_monthly_hours  \
# 0      13697             0.99               3                 161.39
# 1       1142             1.00               5                 226.22
# 2       7954             0.91               5                 199.45
# 3       2225             0.51               3                 235.14
# 4       9753             0.89               3                 219.91
# ...      ...              ...             ...                    ...
# 11994  11971             0.89               4                 150.45
# 11995  14966             0.81               5                 221.28
# 11996   7491             0.60               4                 136.36
# 11997  12680             0.84               6                 268.54
# 11998   9056             0.84               2                 191.60
#
#        time_spend_company  Work_accident  package  promotion_last_5years  \
# 0                       2              0        0                      0
# 1                       6              0        1                      0
# 2                       2              0        4                      0
# 3                       3              0        2                      0
# 4                       2              0        0                      0
# ...                   ...            ...      ...                    ...
# 11994                   3              0        4                      0
# 11995                   5              0        1                      0
# 11996                   4              1        2                      0
# 11997                   4              0        1                      0
# 11998                   3              0        2                      0
#
#        division  salary  satisfaction_level
# 0             2       2               0.681
# 1             5       1               0.876
# 2             7       2               0.955
# 3             7       1               0.817
# 4             9       1               0.920
# ...         ...     ...                 ...
# 11994         2       0               0.849
# 11995         7       1               0.836
# 11996         7       2               0.915
# 11997         0       1               0.099
# 11998         8       1               0.738
#
# [11999 rows x 11 columns]

# %%
X=data_train.iloc[:,1:-1]
y=data_train.iloc[:,-1]
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
X=mm.fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=90)

# %% [markdown]
# # 建模

# %%
X_train.shape
# Out:
# (9599, 9)

# %%
from keras import layers,models
from keras import optimizers
model=models.Sequential()
model.add(layers.Dense(32,input_dim=9,activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1))
adam=optimizers.Adam(lr=0.001)
model.compile(optimizer=adam,loss='mse',metrics=["mse"])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 32)                320
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 865
# Trainable params: 865
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_train,y_train,batch_size=1,epochs=20,validation_data=(X_test,y_test))
# Out:
# Train on 9599 samples, validate on 2400 samples
# Epoch 1/20
# 9599/9599 [==============================] - 27s 3ms/step - loss: 0.0666 - mse: 0.0666 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 2/20
# 9599/9599 [==============================] - 22s 2ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0407 - val_mse: 0.0407
# Epoch 3/20
# 9599/9599 [==============================] - 23s 2ms/step - loss: 0.0454 - mse: 0.0454 - val_loss: 0.0402 - val_mse: 0.0402
# Epoch 4/20
# 9599/9599 [==============================] - 23s 2ms/step - loss: 0.0444 - mse: 0.0444 - val_loss: 0.0405 - val_mse: 0.0405
# Epoch 5/20
# 9599/9599 [==============================] - 23s 2ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0388 - val_mse: 0.0388
# Epoch 6/20
# 9599/9599 [==============================] - 24s 2ms/step - loss: 0.0430 - mse: 0.0430 - val_loss: 0.0398 - val_mse: 0.0398
# Epoch 7/20
# 9599/9599 [==============================] - 23s 2ms/step - loss: 0.0433 - mse: 0.0433 - val_loss: 0.0396 - val_mse: 0.0396
# Epoch 8/20
# 9599/9599 [==============================] - 26s 3ms/step - loss: 0.0433 - mse: 0.0433 - val_loss: 0.0393 - val_mse: 0.0393
# Epoch 9/20
# 9599/9599 [==============================] - 26s 3ms/step - loss: 0.0426 - mse: 0.0426 - val_loss: 0.0383 - val_mse: 0.0383
# Epoch 10/20
# 9599/9599 [==============================] - 26s 3ms/step - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0382 - val_mse: 0.0382
# Epoch 11/20
# 9599/9599 [==============================] - 24s 2ms/step - loss: 0.0427 - mse: 0.0427 - val_loss: 0.0379 - val_mse: 0.0379
# Epoch 12/20
# 9599/9599 [==============================] - 21s 2ms/step - loss: 0.0425 - mse: 0.0425 - val_loss: 0.0394 - val_mse: 0.0394
# Epoch 13/20
# 9599/9599 [==============================] - 24s 3ms/step - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0377 - val_mse: 0.0377
# Epoch 14/20
# 9599/9599 [==============================] - 24s 2ms/step - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0374 - val_mse: 0.0374
# Epoch 15/20
# 9599/9599 [==============================] - 24s 2ms/step - loss: 0.0425 - mse: 0.0425 - val_loss: 0.0375 - val_mse: 0.0375
# Epoch 16/20
# 9599/9599 [==============================] - 24s 2ms/step - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0388 - val_mse: 0.0388
# Epoch 17/20
# 9599/9599 [==============================] - 21s 2ms/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0384 - val_mse: 0.0384
# Epoch 18/20
# 9599/9599 [==============================] - 23s 2ms/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0395 - val_mse: 0.0395
# Epoch 19/20
# 9599/9599 [==============================] - 24s 2ms/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0377 - val_mse: 0.0377
# Epoch 20/20
# 9599/9599 [==============================] - 24s 2ms/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0379 - val_mse: 0.0379

# %%
history_dict = history.history
print(history_dict)
# Out:
# {'val_loss': [0.043357226527618226, 0.040746684039917394, 0.04022760758013545, 0.040501843537736316, 0.03875502267477826, 0.03979314590274835, 0.039624212576844425, 0.03928188012396288, 0.03828281615614392, 0.0382420509992866, 0.03794196374806757, 0.039431953776718535, 0.03768637431622252, 0.037395755831497964, 0.03745433651576825, 0.03884108824203664, 0.03836165338092969, 0.03952841234269481, 0.03771977032487564, 0.03791699767888577], 'val_mse': [0.04335726425051689, 0.040746625512838364, 0.04022759199142456, 0.04050184413790703, 0.03875504061579704, 0.039793167263269424, 0.0396241620182991, 0.03928188607096672, 0.038282789289951324, 0.03824206814169884, 0.03794197738170624, 0.03943200781941414, 0.03768640384078026, 0.037395793944597244, 0.037454333156347275, 0.03884107246994972, 0.038361623883247375, 0.039528414607048035, 0.037719856947660446, 0.03791699931025505], 'loss': [0.066585613003861, 0.04913093318814247, 0.04535850870715237, 0.04439675872635852, 0.043555529771197685, 0.04302291385635097, 0.043257746980514995, 0.043279002749484194, 0.04255674215357151, 0.04237665494454249, 0.04272895478632089, 0.04253491673685058, 0.04232793871520185, 0.04174083106454868, 0.04254389469635876, 0.04225704220176085, 0.04190029459012135, 0.04163827701237115, 0.041891883749720776, 0.042198546934361154], 'mse': [0.06658565, 0.049130857, 0.04535843, 0.044396713, 0.043555498, 0.043022882, 0.04325767, 0.043278955, 0.042556718, 0.042376637, 0.042729005, 0.04253488, 0.042327978, 0.041740797, 0.04254393, 0.042257037, 0.041900422, 0.041638285, 0.041891906, 0.042198468]}

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
mse = history_dict['mse']
epochs = range(1, len(mse) + 1)
 
plt.plot(epochs, loss_values, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss_values, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()# 
mse_values = history_dict['mse']
val_mse_values = history_dict['val_mse']
 
plt.plot(epochs, mse_values, 'bo', label = 'Training mse')
plt.plot(epochs, val_mse_values, 'b', label = 'Validation mse')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Mse')
plt.legend()
plt.show()

# %% [markdown]
# # 预测和文件输出

# %% [markdown]
# ## 测试数据提取

# %%
data_test
# Out:
#          id  last_evaluation  number_project  average_monthly_hours  \
# 0      4615             0.78               4                 260.71
# 1      1680             0.96               7                 275.38
# 2      8866             0.57               4                 207.29
# 3      7525             0.89               5                 150.70
# 4      5389             0.93               3                 141.23
# ...     ...              ...             ...                    ...
# 2995   8434             0.45               3                 132.90
# 2996  14013             0.73               4                 245.77
# 2997  10221             0.75               4                 242.90
# 2998  12847             0.70               3                 235.52
# 2999  12036             0.46               2                 137.19
#
#       time_spend_company  Work_accident  package  promotion_last_5years  \
# 0                      2              0        4                      0
# 1                      5              0        1                      0
# 2                      5              0        4                      0
# 3                      4              0        2                      0
# 4                      2              0        4                      0
# ...                  ...            ...      ...                    ...
# 2995                   2              0        2                      0
# 2996                   2              0        0                      0
# 2997                   4              0        0                      0
# 2998                   4              0        2                      0
# 2999                   3              0        1                      0
#
#       division  salary
# 0            9       2
# 1            5       1
# 2            7       1
# 3            9       2
# 4            8       2
# ...        ...     ...
# 2995         9       1
# 2996         7       1
# 2997         6       1
# 2998         2       0
# 2999         9       1
#
# [3000 rows x 10 columns]

# %%
test_file=data_test.iloc[:,1:]
test_file=mm.fit_transform(test_file)

# %%
model.predict(test_file)
# Out:
# array([[0.6916708 ],
#        [0.15709645],
#        [0.59357005],
#        ...,
#        [0.6858162 ],
#        [0.6858162 ],
#        [0.44200757]], dtype=float32)
